# %%
#install dependencies 
#pip install torch==1.12.1+cu113 torchvision==0.13.1+cu113 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu113
#pip install torch-sparse -f https://data.pyg.org/whl/torch-1.12.1+cu113.html
#pip install torch-scatter -f https://data.pyg.org/whl/torch-1.12.1+cu113.html
#pip install torch-geometric
#pip install open3d
#pip install pandas

# %%
from pathlib import Path
import glob
import os
import numpy as np
import pandas as pd

import torch
import open3d as o3d

print(torch.__version__)

# %%
path = "C:/Users/aorhu/Masaüstü/ADLM/repo/BodyMeshGNN/1119738/body_surface_mesh.pt"

# %%
data_sample = torch.load(path)

# %%
data_sample.edge_index
# Out:
# tensor([[     2,      4,      0,  ..., 248088, 248047, 248088],
#         [     1,      3,      3,  ..., 248087, 248040, 248042]])

# %%
data_sample.eid

# %%
# with open3d: point cloud
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(np.asarray(data_sample.x))

o3d.visualization.draw_geometries([pcd])

# %%
# with open3d: triangle mesh (need face info)
# mesh = o3d.geometry.TriangleMesh()
# mesh.vertices = o3d.utility.Vector3dVector(np.asarray(data_sample.x))
# mesh.triangles = o3d.utility.Vector3dVector(np.asarray(data_sample.edge))

# %%
# with open3d: graph
lines = o3d.utility.Vector2iVector(np.asarray(data_sample.edge_index.T))
line_set = o3d.geometry.LineSet(
        points=o3d.utility.Vector3dVector(np.asarray(data_sample.x)),
        lines=lines)

line_set.colors = o3d.utility.Vector3dVector([[1, 0, 0] for i in range(len(lines))])

o3d.visualization.draw_geometries([line_set])

# %%
# reading ID mapping
id_map_path = "C:/Users/aorhu/Masaüstü/ADLM/Bridge_eids_60520_87802.csv"

# %%
id_map = pd.read_csv(id_map_path)

# %%
id_map

# %%
# reading basic_features

# %%
basic_features_path = "C:/Users/aorhu/Masaüstü/ADLM/basic_features.csv"

# %%
basic_features = pd.read_csv(basic_features_path)

# %%
basic_features

# %%
#reading file directories for patients into dictionary

# %%
DATA_ROOT = Path("D:/ADLM Data/body_meshes/")

map_dict = {}

# %%
for file in os.listdir(str(DATA_ROOT)):
    _path = os.path.join(str(DATA_ROOT), file).replace('\\', '/')

    sex = "female" if int(basic_features["31-0.0"][basic_features.index[basic_features['eid'] == int(file)]]) == 0 else "male"
    
    map_dict[file] = dict({'path': str(_path) +'/body_surface_mesh.pt',
                           'old_id': int(id_map["eid_60520"][id_map.index[id_map['eid_87802'] == int(file)]]),
                           'sex': sex})

# %%
map_dict
# Out:
# {'1000071': {'path': 'D:/ADLM Data/body_meshes/1000071/body_surface_mesh.pt',
#   'old_id': 2119543,
#   'sex': 'female'},
#  '1000109': {'path': 'D:/ADLM Data/body_meshes/1000109/body_surface_mesh.pt',
#   'old_id': 1018162,
#   'sex': 'female'},
#  '1000125': {'path': 'D:/ADLM Data/body_meshes/1000125/body_surface_mesh.pt',
#   'old_id': 5950933,
#   'sex': 'male'},
#  '1000180': {'path': 'D:/ADLM Data/body_meshes/1000180/body_surface_mesh.pt',
#   'old_id': 3624064,
#   'sex': 'male'},
#  '1000191': {'path': 'D:/ADLM Data/body_meshes/1000191/body_surface_mesh.pt',
#   'old_id': 3092647,
#   'sex': 'male'},
#  '1000352': {'path': 'D:/ADLM Data/body_meshes/1000352/body_surface_mesh.pt',
#   'old_id': 5806236,
#   'sex': 'male'},
#  '1000456': {'path': 'D:/ADLM Data/body_meshes/1000456/body_surface_mesh.pt',
#   'old_id': 3829892,
#   'sex': 'male'},
#  '1000721': {'path': 'D:/ADLM Data/body_meshes/1000721/body_surface_mesh.pt',
#   'old_id': 3284899,
#   'sex': 'male'},
#  '1000770': {'path': 'D:/ADLM Data/body_meshes/1000770/body_surface_mesh.pt',
#   'old_id': 3037395,
#   'sex': 'female'},
#  '1000812': {'path': 'D:/ADLM Data/body_meshes/1000812/body_surface_mesh.pt',
#   'old_id': 1082599,
#   'sex': 'male'},
#  '1000900': {'path': 'D:/ADLM Data/body_meshes/1000900/body_surface_mesh.pt',
#   'old_id': 2163269,
#   'sex': 'female'},
#  '1000969': {'path': 'D:/ADLM Data/body_meshes/1000969/body_surface_mesh.pt',
#   'old_id': 2793203,
#   'sex': 'male'},
#  '1001062': {'path': 'D:/ADLM Data/body_meshes/1001062/body_surface_mesh.pt',
#   'old_id': 3151891,
#   'sex': 'female'},
#  '1001146': {'path': 'D:/ADLM Data/body_meshes/1001146/body_surface_mesh.pt',
#   'old_id': 3071340,
#   'sex': 'female'},
#  '1001399': {'path': 'D:/ADLM Data/body_meshes/1001399/body_surface_mesh.pt',
#   'old_id': 3483377,
#   'sex': 'female'},
#  '1001544': {'path': 'D:/ADLM Data/body_meshes/1001544/body_surface_mesh.pt',
#   'old_id': 2265223,
#   'sex': 'female'},
#  '1001948': {'path': 'D:/ADLM Data/body_meshes/1001948/body_surface_mesh.pt',
#   'old_id': 3801904,
#   'sex': 'male'},
#  '1001991': {'path': 'D:/ADLM Data/body_meshes/1001991/body_surface_mesh.pt',
#   'old_id': 2037433,
#   'sex': 'female'},
#  '1002003': {'path': 'D:/ADLM Data/body_meshes/1002003/body_surface_mesh.pt',
#   'old_id': 2197513,
#   'sex': 'female'},
#  '1002121': {'path': 'D:/ADLM Data/body_meshes/1002121/body_surface_mesh.pt',
#   'old_id': 4240959,
#   'sex': 'male'},
#  '1002222': {'path': 'D:/ADLM Data/body_meshes/1002222/body_surface_mesh.pt',
#   'old_id': 2283578,
#   'sex': 'female'},
#  '1002236': {'path': 'D:/ADLM Data/body_meshes/1002236/body_surface_mesh.pt',
#   'old_id': 2158698,
#   'sex': 'female'},
#  '1002371': {'path': 'D:/ADLM Data/body_meshes/1002371/body_surface_mesh.pt',
#   'old_id': 5969244,
#   'sex': 'female'},
#  '1002523': {'path': 'D:/ADLM Data/body_meshes/1002523/body_surface_mesh.pt',
#   'old_id': 3520651,
#   'sex': 'female'},
#  '1002559': {'path': 'D:/ADLM Data/body_meshes/1002559/body_surface_mesh.pt',
#   'old_id': 3262215,
#   'sex': 'male'},
#  '1002693': {'path': 'D:/ADLM Data/body_meshes/1002693/body_surface_mesh.pt',
#   'old_id': 2054890,
#   'sex': 'male'},
#  '1002754': {'path': 'D:/ADLM Data/body_meshes/1002754/body_surface_mesh.pt',
#   'old_id': 1216294,
#   'sex': 'female'},
#  '1002881': {'path': 'D:/ADLM Data/body_meshes/1002881/body_surface_mesh.pt',
#   'old_id': 3671774,
#   'sex': 'male'},
#  '1002897': {'path': 'D:/ADLM Data/body_meshes/1002897/body_surface_mesh.pt',
#   'old_id': 5533141,
#   'sex': 'female'},
#  '1002951': {'path': 'D:/ADLM Data/body_meshes/1002951/body_surface_mesh.pt',
#   'old_id': 2186443,
#   'sex': 'female'},
#  '1003119': {'path': 'D:/ADLM Data/body_meshes/1003119/body_surface_mesh.pt',
#   'old_id': 2851514,
#   'sex': 'male'},
#  '1003237': {'path': 'D:/ADLM Data/body_meshes/1003237/body_surface_mesh.pt',
#   'old_id': 3996944,
#   'sex': 'male'},
#  '1003251': {'path': 'D:/ADLM Data/body_meshes/1003251/body_surface_mesh.pt',
#   'old_id': 5193539,
#   'sex': 'male'},
#  '1003355': {'path': 'D:/ADLM Data/body_meshes/1003355/body_surface_mesh.pt',
#   'old_id': 4090996,
#   'sex': 'male'},
#  '1003657': {'path': 'D:/ADLM Data/body_meshes/1003657/body_surface_mesh.pt',
#   'old_id': 2646188,
#   'sex': 'male'},
#  '1003798': {'path': 'D:/ADLM Data/body_meshes/1003798/body_surface_mesh.pt',
#   'old_id': 3181455,
#   'sex': 'female'},
#  '1003864': {'path': 'D:/ADLM Data/body_meshes/1003864/body_surface_mesh.pt',
#   'old_id': 4671351,
#   'sex': 'male'},
#  '1003910': {'path': 'D:/ADLM Data/body_meshes/1003910/body_surface_mesh.pt',
#   'old_id': 3361022,
#   'sex': 'male'},
#  '1004032': {'path': 'D:/ADLM Data/body_meshes/1004032/body_surface_mesh.pt',
#   'old_id': 5728364,
#   'sex': 'female'},
#  '1004054': {'path': 'D:/ADLM Data/body_meshes/1004054/body_surface_mesh.pt',
#   'old_id': 1793897,
#   'sex': 'male'},
#  '1004127': {'path': 'D:/ADLM Data/body_meshes/1004127/body_surface_mesh.pt',
#   'old_id': 5491757,
#   'sex': 'male'},
#  '1004224': {'path': 'D:/ADLM Data/body_meshes/1004224/body_surface_mesh.pt',
#   'old_id': 2683171,
#   'sex': 'female'},
#  '1004267': {'path': 'D:/ADLM Data/body_meshes/1004267/body_surface_mesh.pt',
#   'old_id': 3211904,
#   'sex': 'female'},
#  '1004275': {'path': 'D:/ADLM Data/body_meshes/1004275/body_surface_mesh.pt',
#   'old_id': 3857195,
#   'sex': 'female'},
#  '1004505': {'path': 'D:/ADLM Data/body_meshes/1004505/body_surface_mesh.pt',
#   'old_id': 2503035,
#   'sex': 'male'},
#  '1004573': {'path': 'D:/ADLM Data/body_meshes/1004573/body_surface_mesh.pt',
#   'old_id': 1953250,
#   'sex': 'female'},
#  '1004674': {'path': 'D:/ADLM Data/body_meshes/1004674/body_surface_mesh.pt',
#   'old_id': 5313708,
#   'sex': 'female'},
#  '1004683': {'path': 'D:/ADLM Data/body_meshes/1004683/body_surface_mesh.pt',
#   'old_id': 2750821,
#   'sex': 'female'},
#  '1004755': {'path': 'D:/ADLM Data/body_meshes/1004755/body_surface_mesh.pt',
#   'old_id': 5695904,
#   'sex': 'male'},
#  '1005130': {'path': 'D:/ADLM Data/body_meshes/1005130/body_surface_mesh.pt',
#   'old_id': 5652145,
#   'sex': 'female'},
#  '1005350': {'path': 'D:/ADLM Data/body_meshes/1005350/body_surface_mesh.pt',
#   'old_id': 2108542,
#   'sex': 'male'},
#  '1005760': {'path': 'D:/ADLM Data/body_meshes/1005760/body_surface_mesh.pt',
#   'old_id': 1150254,
#   'sex': 'female'},
#  '1005787': {'path': 'D:/ADLM Data/body_meshes/1005787/body_surface_mesh.pt',
#   'old_id': 5809705,
#   'sex': 'female'},
#  '1005899': {'path': 'D:/ADLM Data/body_meshes/1005899/body_surface_mesh.pt',
#   'old_id': 2565378,
#   'sex': 'male'},
#  '1005915': {'path': 'D:/ADLM Data/body_meshes/1005915/body_surface_mesh.pt',
#   'old_id': 5960418,
#   'sex': 'male'},
#  '1006281': {'path': 'D:/ADLM Data/body_meshes/1006281/body_surface_mesh.pt',
#   'old_id': 3198067,
#   'sex': 'male'},
#  '1006533': {'path': 'D:/ADLM Data/body_meshes/1006533/body_surface_mesh.pt',
#   'old_id': 3885622,
#   'sex': 'male'},
#  '1006549': {'path': 'D:/ADLM Data/body_meshes/1006549/body_surface_mesh.pt',
#   'old_id': 3215204,
#   'sex': 'male'},
#  '1006722': {'path': 'D:/ADLM Data/body_meshes/1006722/body_surface_mesh.pt',
#   'old_id': 1766164,
#   'sex': 'female'},
#  '1006799': {'path': 'D:/ADLM Data/body_meshes/1006799/body_surface_mesh.pt',
#   'old_id': 4227714,
#   'sex': 'female'},
#  '1006838': {'path': 'D:/ADLM Data/body_meshes/1006838/body_surface_mesh.pt',
#   'old_id': 2972960,
#   'sex': 'female'},
#  '1006959': {'path': 'D:/ADLM Data/body_meshes/1006959/body_surface_mesh.pt',
#   'old_id': 2758734,
#   'sex': 'female'},
#  '1007079': {'path': 'D:/ADLM Data/body_meshes/1007079/body_surface_mesh.pt',
#   'old_id': 4467401,
#   'sex': 'male'},
#  '1007145': {'path': 'D:/ADLM Data/body_meshes/1007145/body_surface_mesh.pt',
#   'old_id': 5379710,
#   'sex': 'male'},
#  '1007249': {'path': 'D:/ADLM Data/body_meshes/1007249/body_surface_mesh.pt',
#   'old_id': 3015929,
#   'sex': 'female'},
#  '1007640': {'path': 'D:/ADLM Data/body_meshes/1007640/body_surface_mesh.pt',
#   'old_id': 2895318,
#   'sex': 'female'},
#  '1007750': {'path': 'D:/ADLM Data/body_meshes/1007750/body_surface_mesh.pt',
#   'old_id': 2317420,
#   'sex': 'male'},
#  '1007841': {'path': 'D:/ADLM Data/body_meshes/1007841/body_surface_mesh.pt',
#   'old_id': 3520181,
#   'sex': 'female'},
#  '1007967': {'path': 'D:/ADLM Data/body_meshes/1007967/body_surface_mesh.pt',
#   'old_id': 2475243,
#   'sex': 'male'},
#  '1008045': {'path': 'D:/ADLM Data/body_meshes/1008045/body_surface_mesh.pt',
#   'old_id': 5195692,
#   'sex': 'male'},
#  '1008168': {'path': 'D:/ADLM Data/body_meshes/1008168/body_surface_mesh.pt',
#   'old_id': 1928538,
#   'sex': 'female'},
#  '1008293': {'path': 'D:/ADLM Data/body_meshes/1008293/body_surface_mesh.pt',
#   'old_id': 1334658,
#   'sex': 'male'},
#  '1008370': {'path': 'D:/ADLM Data/body_meshes/1008370/body_surface_mesh.pt',
#   'old_id': 2902607,
#   'sex': 'male'},
#  '1008430': {'path': 'D:/ADLM Data/body_meshes/1008430/body_surface_mesh.pt',
#   'old_id': 4091421,
#   'sex': 'female'},
#  '1008947': {'path': 'D:/ADLM Data/body_meshes/1008947/body_surface_mesh.pt',
#   'old_id': 2654121,
#   'sex': 'male'},
#  '1009041': {'path': 'D:/ADLM Data/body_meshes/1009041/body_surface_mesh.pt',
#   'old_id': 3411369,
#   'sex': 'female'},
#  '1009169': {'path': 'D:/ADLM Data/body_meshes/1009169/body_surface_mesh.pt',
#   'old_id': 2690915,
#   'sex': 'female'},
#  '1009231': {'path': 'D:/ADLM Data/body_meshes/1009231/body_surface_mesh.pt',
#   'old_id': 4164567,
#   'sex': 'female'},
#  '1009474': {'path': 'D:/ADLM Data/body_meshes/1009474/body_surface_mesh.pt',
#   'old_id': 2974733,
#   'sex': 'female'},
#  '1009499': {'path': 'D:/ADLM Data/body_meshes/1009499/body_surface_mesh.pt',
#   'old_id': 1956415,
#   'sex': 'male'},
#  '1009575': {'path': 'D:/ADLM Data/body_meshes/1009575/body_surface_mesh.pt',
#   'old_id': 5889022,
#   'sex': 'female'},
#  '1009727': {'path': 'D:/ADLM Data/body_meshes/1009727/body_surface_mesh.pt',
#   'old_id': 3809188,
#   'sex': 'male'},
#  '1009857': {'path': 'D:/ADLM Data/body_meshes/1009857/body_surface_mesh.pt',
#   'old_id': 4524194,
#   'sex': 'female'},
#  '1009901': {'path': 'D:/ADLM Data/body_meshes/1009901/body_surface_mesh.pt',
#   'old_id': 4653014,
#   'sex': 'female'},
#  '1009944': {'path': 'D:/ADLM Data/body_meshes/1009944/body_surface_mesh.pt',
#   'old_id': 3293311,
#   'sex': 'female'},
#  '1010183': {'path': 'D:/ADLM Data/body_meshes/1010183/body_surface_mesh.pt',
#   'old_id': 1573039,
#   'sex': 'female'},
#  '1010319': {'path': 'D:/ADLM Data/body_meshes/1010319/body_surface_mesh.pt',
#   'old_id': 1632614,
#   'sex': 'female'},
#  '1010328': {'path': 'D:/ADLM Data/body_meshes/1010328/body_surface_mesh.pt',
#   'old_id': 1790347,
#   'sex': 'male'},
#  '1010335': {'path': 'D:/ADLM Data/body_meshes/1010335/body_surface_mesh.pt',
#   'old_id': 1954541,
#   'sex': 'male'},
#  '1010534': {'path': 'D:/ADLM Data/body_meshes/1010534/body_surface_mesh.pt',
#   'old_id': 3835017,
#   'sex': 'male'},
#  '1010555': {'path': 'D:/ADLM Data/body_meshes/1010555/body_surface_mesh.pt',
#   'old_id': 1151793,
#   'sex': 'male'},
#  '1010747': {'path': 'D:/ADLM Data/body_meshes/1010747/body_surface_mesh.pt',
#   'old_id': 2577999,
#   'sex': 'male'},
#  '1010841': {'path': 'D:/ADLM Data/body_meshes/1010841/body_surface_mesh.pt',
#   'old_id': 4104882,
#   'sex': 'female'},
#  '1010911': {'path': 'D:/ADLM Data/body_meshes/1010911/body_surface_mesh.pt',
#   'old_id': 3812296,
#   'sex': 'female'},
#  '1011101': {'path': 'D:/ADLM Data/body_meshes/1011101/body_surface_mesh.pt',
#   'old_id': 2414244,
#   'sex': 'female'},
#  '1011128': {'path': 'D:/ADLM Data/body_meshes/1011128/body_surface_mesh.pt',
#   'old_id': 5248137,
#   'sex': 'female'},
#  '1011144': {'path': 'D:/ADLM Data/body_meshes/1011144/body_surface_mesh.pt',
#   'old_id': 3278112,
#   'sex': 'male'},
#  '1011220': {'path': 'D:/ADLM Data/body_meshes/1011220/body_surface_mesh.pt',
#   'old_id': 4903575,
#   'sex': 'male'},
#  '1011243': {'path': 'D:/ADLM Data/body_meshes/1011243/body_surface_mesh.pt',
#   'old_id': 4558712,
#   'sex': 'male'},
#  '1011334': {'path': 'D:/ADLM Data/body_meshes/1011334/body_surface_mesh.pt',
#   'old_id': 5210317,
#   'sex': 'male'},
#  '1011424': {'path': 'D:/ADLM Data/body_meshes/1011424/body_surface_mesh.pt',
#   'old_id': 4220128,
#   'sex': 'male'},
#  '1011525': {'path': 'D:/ADLM Data/body_meshes/1011525/body_surface_mesh.pt',
#   'old_id': 2872157,
#   'sex': 'male'},
#  '1011580': {'path': 'D:/ADLM Data/body_meshes/1011580/body_surface_mesh.pt',
#   'old_id': 3534656,
#   'sex': 'male'},
#  '1011670': {'path': 'D:/ADLM Data/body_meshes/1011670/body_surface_mesh.pt',
#   'old_id': 4836427,
#   'sex': 'male'},
#  '1012035': {'path': 'D:/ADLM Data/body_meshes/1012035/body_surface_mesh.pt',
#   'old_id': 1901338,
#   'sex': 'female'},
#  '1012087': {'path': 'D:/ADLM Data/body_meshes/1012087/body_surface_mesh.pt',
#   'old_id': 3276824,
#   'sex': 'female'},
#  '1012213': {'path': 'D:/ADLM Data/body_meshes/1012213/body_surface_mesh.pt',
#   'old_id': 5881742,
#   'sex': 'male'},
#  '1012368': {'path': 'D:/ADLM Data/body_meshes/1012368/body_surface_mesh.pt',
#   'old_id': 4884763,
#   'sex': 'male'},
#  '1012488': {'path': 'D:/ADLM Data/body_meshes/1012488/body_surface_mesh.pt',
#   'old_id': 3712042,
#   'sex': 'female'},
#  '1012496': {'path': 'D:/ADLM Data/body_meshes/1012496/body_surface_mesh.pt',
#   'old_id': 5907774,
#   'sex': 'male'},
#  '1012570': {'path': 'D:/ADLM Data/body_meshes/1012570/body_surface_mesh.pt',
#   'old_id': 3882019,
#   'sex': 'male'},
#  '1012691': {'path': 'D:/ADLM Data/body_meshes/1012691/body_surface_mesh.pt',
#   'old_id': 5487101,
#   'sex': 'male'},
#  '1012707': {'path': 'D:/ADLM Data/body_meshes/1012707/body_surface_mesh.pt',
#   'old_id': 2316499,
#   'sex': 'male'},
#  '1012959': {'path': 'D:/ADLM Data/body_meshes/1012959/body_surface_mesh.pt',
#   'old_id': 1235838,
#   'sex': 'male'},
#  '1013053': {'path': 'D:/ADLM Data/body_meshes/1013053/body_surface_mesh.pt',
#   'old_id': 3540752,
#   'sex': 'female'},
#  '1013241': {'path': 'D:/ADLM Data/body_meshes/1013241/body_surface_mesh.pt',
#   'old_id': 1151875,
#   'sex': 'female'},
#  '1013352': {'path': 'D:/ADLM Data/body_meshes/1013352/body_surface_mesh.pt',
#   'old_id': 2044756,
#   'sex': 'female'},
#  '1013493': {'path': 'D:/ADLM Data/body_meshes/1013493/body_surface_mesh.pt',
#   'old_id': 1702330,
#   'sex': 'male'},
#  '1013843': {'path': 'D:/ADLM Data/body_meshes/1013843/body_surface_mesh.pt',
#   'old_id': 4619727,
#   'sex': 'male'},
#  '1013879': {'path': 'D:/ADLM Data/body_meshes/1013879/body_surface_mesh.pt',
#   'old_id': 2562478,
#   'sex': 'male'},
#  '1013900': {'path': 'D:/ADLM Data/body_meshes/1013900/body_surface_mesh.pt',
#   'old_id': 1108438,
#   'sex': 'female'},
#  '1013913': {'path': 'D:/ADLM Data/body_meshes/1013913/body_surface_mesh.pt',
#   'old_id': 3696240,
#   'sex': 'male'},
#  '1013997': {'path': 'D:/ADLM Data/body_meshes/1013997/body_surface_mesh.pt',
#   'old_id': 4425627,
#   'sex': 'male'},
#  '1014022': {'path': 'D:/ADLM Data/body_meshes/1014022/body_surface_mesh.pt',
#   'old_id': 5569472,
#   'sex': 'male'},
#  '1014194': {'path': 'D:/ADLM Data/body_meshes/1014194/body_surface_mesh.pt',
#   'old_id': 1472640,
#   'sex': 'female'},
#  '1014256': {'path': 'D:/ADLM Data/body_meshes/1014256/body_surface_mesh.pt',
#   'old_id': 2081118,
#   'sex': 'female'},
#  '1014416': {'path': 'D:/ADLM Data/body_meshes/1014416/body_surface_mesh.pt',
#   'old_id': 1709871,
#   'sex': 'female'},
#  '1014423': {'path': 'D:/ADLM Data/body_meshes/1014423/body_surface_mesh.pt',
#   'old_id': 2422729,
#   'sex': 'male'},
#  '1014564': {'path': 'D:/ADLM Data/body_meshes/1014564/body_surface_mesh.pt',
#   'old_id': 3955200,
#   'sex': 'male'},
#  '1014626': {'path': 'D:/ADLM Data/body_meshes/1014626/body_surface_mesh.pt',
#   'old_id': 2177444,
#   'sex': 'male'},
#  '1014697': {'path': 'D:/ADLM Data/body_meshes/1014697/body_surface_mesh.pt',
#   'old_id': 3471957,
#   'sex': 'male'},
#  '1014918': {'path': 'D:/ADLM Data/body_meshes/1014918/body_surface_mesh.pt',
#   'old_id': 1193156,
#   'sex': 'male'},
#  '1015114': {'path': 'D:/ADLM Data/body_meshes/1015114/body_surface_mesh.pt',
#   'old_id': 2191779,
#   'sex': 'male'},
#  '1015299': {'path': 'D:/ADLM Data/body_meshes/1015299/body_surface_mesh.pt',
#   'old_id': 5149750,
#   'sex': 'female'},
#  '1015302': {'path': 'D:/ADLM Data/body_meshes/1015302/body_surface_mesh.pt',
#   'old_id': 4483394,
#   'sex': 'female'},
#  '1015429': {'path': 'D:/ADLM Data/body_meshes/1015429/body_surface_mesh.pt',
#   'old_id': 4238603,
#   'sex': 'male'},
#  '1015484': {'path': 'D:/ADLM Data/body_meshes/1015484/body_surface_mesh.pt',
#   'old_id': 1006327,
#   'sex': 'female'},
#  '1015693': {'path': 'D:/ADLM Data/body_meshes/1015693/body_surface_mesh.pt',
#   'old_id': 2929697,
#   'sex': 'male'},
#  '1015842': {'path': 'D:/ADLM Data/body_meshes/1015842/body_surface_mesh.pt',
#   'old_id': 4400391,
#   'sex': 'male'},
#  '1015897': {'path': 'D:/ADLM Data/body_meshes/1015897/body_surface_mesh.pt',
#   'old_id': 2543067,
#   'sex': 'male'},
#  '1016153': {'path': 'D:/ADLM Data/body_meshes/1016153/body_surface_mesh.pt',
#   'old_id': 2141398,
#   'sex': 'male'},
#  '1016246': {'path': 'D:/ADLM Data/body_meshes/1016246/body_surface_mesh.pt',
#   'old_id': 3183066,
#   'sex': 'female'},
#  '1016267': {'path': 'D:/ADLM Data/body_meshes/1016267/body_surface_mesh.pt',
#   'old_id': 4993433,
#   'sex': 'male'},
#  '1016359': {'path': 'D:/ADLM Data/body_meshes/1016359/body_surface_mesh.pt',
#   'old_id': 5180811,
#   'sex': 'female'},
#  '1016420': {'path': 'D:/ADLM Data/body_meshes/1016420/body_surface_mesh.pt',
#   'old_id': 5126066,
#   'sex': 'female'},
#  '1016494': {'path': 'D:/ADLM Data/body_meshes/1016494/body_surface_mesh.pt',
#   'old_id': 2100797,
#   'sex': 'female'},
#  '1016683': {'path': 'D:/ADLM Data/body_meshes/1016683/body_surface_mesh.pt',
#   'old_id': 2314463,
#   'sex': 'female'},
#  '1016755': {'path': 'D:/ADLM Data/body_meshes/1016755/body_surface_mesh.pt',
#   'old_id': 2932264,
#   'sex': 'male'},
#  '1016933': {'path': 'D:/ADLM Data/body_meshes/1016933/body_surface_mesh.pt',
#   'old_id': 4181227,
#   'sex': 'female'},
#  '1017065': {'path': 'D:/ADLM Data/body_meshes/1017065/body_surface_mesh.pt',
#   'old_id': 2273538,
#   'sex': 'female'},
#  '1017100': {'path': 'D:/ADLM Data/body_meshes/1017100/body_surface_mesh.pt',
#   'old_id': 5391289,
#   'sex': 'male'},
#  '1017113': {'path': 'D:/ADLM Data/body_meshes/1017113/body_surface_mesh.pt',
#   'old_id': 2732779,
#   'sex': 'female'},
#  '1017155': {'path': 'D:/ADLM Data/body_meshes/1017155/body_surface_mesh.pt',
#   'old_id': 2395036,
#   'sex': 'female'},
#  '1017266': {'path': 'D:/ADLM Data/body_meshes/1017266/body_surface_mesh.pt',
#   'old_id': 3293487,
#   'sex': 'male'},
#  '1017354': {'path': 'D:/ADLM Data/body_meshes/1017354/body_surface_mesh.pt',
#   'old_id': 5898183,
#   'sex': 'male'},
#  '1017380': {'path': 'D:/ADLM Data/body_meshes/1017380/body_surface_mesh.pt',
#   'old_id': 2241745,
#   'sex': 'female'},
#  '1017590': {'path': 'D:/ADLM Data/body_meshes/1017590/body_surface_mesh.pt',
#   'old_id': 4730104,
#   'sex': 'female'},
#  '1017606': {'path': 'D:/ADLM Data/body_meshes/1017606/body_surface_mesh.pt',
#   'old_id': 3900403,
#   'sex': 'female'},
#  '1017668': {'path': 'D:/ADLM Data/body_meshes/1017668/body_surface_mesh.pt',
#   'old_id': 4137593,
#   'sex': 'female'},
#  '1017814': {'path': 'D:/ADLM Data/body_meshes/1017814/body_surface_mesh.pt',
#   'old_id': 1798257,
#   'sex': 'female'},
#  '1018116': {'path': 'D:/ADLM Data/body_meshes/1018116/body_surface_mesh.pt',
#   'old_id': 4272755,
#   'sex': 'female'},
#  '1018165': {'path': 'D:/ADLM Data/body_meshes/1018165/body_surface_mesh.pt',
#   'old_id': 5931705,
#   'sex': 'male'},
#  '1018232': {'path': 'D:/ADLM Data/body_meshes/1018232/body_surface_mesh.pt',
#   'old_id': 4577894,
#   'sex': 'male'},
#  '1018318': {'path': 'D:/ADLM Data/body_meshes/1018318/body_surface_mesh.pt',
#   'old_id': 2549970,
#   'sex': 'male'},
#  '1018408': {'path': 'D:/ADLM Data/body_meshes/1018408/body_surface_mesh.pt',
#   'old_id': 1457575,
#   'sex': 'male'},
#  '1018506': {'path': 'D:/ADLM Data/body_meshes/1018506/body_surface_mesh.pt',
#   'old_id': 3840492,
#   'sex': 'male'},
#  '1018689': {'path': 'D:/ADLM Data/body_meshes/1018689/body_surface_mesh.pt',
#   'old_id': 1496901,
#   'sex': 'male'},
#  '1018735': {'path': 'D:/ADLM Data/body_meshes/1018735/body_surface_mesh.pt',
#   'old_id': 4528080,
#   'sex': 'male'},
#  '1019008': {'path': 'D:/ADLM Data/body_meshes/1019008/body_surface_mesh.pt',
#   'old_id': 4234260,
#   'sex': 'male'},
#  '1019227': {'path': 'D:/ADLM Data/body_meshes/1019227/body_surface_mesh.pt',
#   'old_id': 1312731,
#   'sex': 'female'},
#  '1019310': {'path': 'D:/ADLM Data/body_meshes/1019310/body_surface_mesh.pt',
#   'old_id': 3890098,
#   'sex': 'female'},
#  '1019426': {'path': 'D:/ADLM Data/body_meshes/1019426/body_surface_mesh.pt',
#   'old_id': 4989115,
#   'sex': 'female'},
#  '1019560': {'path': 'D:/ADLM Data/body_meshes/1019560/body_surface_mesh.pt',
#   'old_id': 2342510,
#   'sex': 'female'},
#  '1019682': {'path': 'D:/ADLM Data/body_meshes/1019682/body_surface_mesh.pt',
#   'old_id': 2447587,
#   'sex': 'female'},
#  '1019768': {'path': 'D:/ADLM Data/body_meshes/1019768/body_surface_mesh.pt',
#   'old_id': 5072106,
#   'sex': 'female'},
#  '1019847': {'path': 'D:/ADLM Data/body_meshes/1019847/body_surface_mesh.pt',
#   'old_id': 2540421,
#   'sex': 'male'},
#  '1019866': {'path': 'D:/ADLM Data/body_meshes/1019866/body_surface_mesh.pt',
#   'old_id': 4488027,
#   'sex': 'female'},
#  '1019917': {'path': 'D:/ADLM Data/body_meshes/1019917/body_surface_mesh.pt',
#   'old_id': 2379627,
#   'sex': 'female'},
#  '1020058': {'path': 'D:/ADLM Data/body_meshes/1020058/body_surface_mesh.pt',
#   'old_id': 2612308,
#   'sex': 'male'},
#  '1020357': {'path': 'D:/ADLM Data/body_meshes/1020357/body_surface_mesh.pt',
#   'old_id': 1034731,
#   'sex': 'female'},
#  '1020502': {'path': 'D:/ADLM Data/body_meshes/1020502/body_surface_mesh.pt',
#   'old_id': 2657489,
#   'sex': 'male'},
#  '1020539': {'path': 'D:/ADLM Data/body_meshes/1020539/body_surface_mesh.pt',
#   'old_id': 3356987,
#   'sex': 'female'},
#  '1020553': {'path': 'D:/ADLM Data/body_meshes/1020553/body_surface_mesh.pt',
#   'old_id': 2446697,
#   'sex': 'male'},
#  '1020891': {'path': 'D:/ADLM Data/body_meshes/1020891/body_surface_mesh.pt',
#   'old_id': 5741867,
#   'sex': 'female'},
#  '1021245': {'path': 'D:/ADLM Data/body_meshes/1021245/body_surface_mesh.pt',
#   'old_id': 3776390,
#   'sex': 'female'},
#  '1021492': {'path': 'D:/ADLM Data/body_meshes/1021492/body_surface_mesh.pt',
#   'old_id': 4190047,
#   'sex': 'male'},
#  '1021530': {'path': 'D:/ADLM Data/body_meshes/1021530/body_surface_mesh.pt',
#   'old_id': 5542143,
#   'sex': 'male'},
#  '1021601': {'path': 'D:/ADLM Data/body_meshes/1021601/body_surface_mesh.pt',
#   'old_id': 1267228,
#   'sex': 'female'},
#  '1021709': {'path': 'D:/ADLM Data/body_meshes/1021709/body_surface_mesh.pt',
#   'old_id': 1262614,
#   'sex': 'male'},
#  '1021717': {'path': 'D:/ADLM Data/body_meshes/1021717/body_surface_mesh.pt',
#   'old_id': 1583578,
#   'sex': 'male'},
#  '1021725': {'path': 'D:/ADLM Data/body_meshes/1021725/body_surface_mesh.pt',
#   'old_id': 4630834,
#   'sex': 'female'},
#  '1021869': {'path': 'D:/ADLM Data/body_meshes/1021869/body_surface_mesh.pt',
#   'old_id': 5590036,
#   'sex': 'male'},
#  '1022033': {'path': 'D:/ADLM Data/body_meshes/1022033/body_surface_mesh.pt',
#   'old_id': 1637404,
#   'sex': 'male'},
#  '1022070': {'path': 'D:/ADLM Data/body_meshes/1022070/body_surface_mesh.pt',
#   'old_id': 1059476,
#   'sex': 'female'},
#  '1022215': {'path': 'D:/ADLM Data/body_meshes/1022215/body_surface_mesh.pt',
#   'old_id': 3670699,
#   'sex': 'female'},
#  '1022336': {'path': 'D:/ADLM Data/body_meshes/1022336/body_surface_mesh.pt',
#   'old_id': 5910000,
#   'sex': 'female'},
#  '1022345': {'path': 'D:/ADLM Data/body_meshes/1022345/body_surface_mesh.pt',
#   'old_id': 4125573,
#   'sex': 'male'},
#  '1022358': {'path': 'D:/ADLM Data/body_meshes/1022358/body_surface_mesh.pt',
#   'old_id': 4953103,
#   'sex': 'male'},
#  '1022442': {'path': 'D:/ADLM Data/body_meshes/1022442/body_surface_mesh.pt',
#   'old_id': 1803291,
#   'sex': 'male'},
#  '1022720': {'path': 'D:/ADLM Data/body_meshes/1022720/body_surface_mesh.pt',
#   'old_id': 1194844,
#   'sex': 'female'},
#  '1022818': {'path': 'D:/ADLM Data/body_meshes/1022818/body_surface_mesh.pt',
#   'old_id': 2541308,
#   'sex': 'male'},
#  '1022932': {'path': 'D:/ADLM Data/body_meshes/1022932/body_surface_mesh.pt',
#   'old_id': 2487219,
#   'sex': 'female'},
#  '1023013': {'path': 'D:/ADLM Data/body_meshes/1023013/body_surface_mesh.pt',
#   'old_id': 4411841,
#   'sex': 'male'},
#  '1023276': {'path': 'D:/ADLM Data/body_meshes/1023276/body_surface_mesh.pt',
#   'old_id': 3244576,
#   'sex': 'male'},
#  '1023305': {'path': 'D:/ADLM Data/body_meshes/1023305/body_surface_mesh.pt',
#   'old_id': 2908717,
#   'sex': 'male'},
#  '1023744': {'path': 'D:/ADLM Data/body_meshes/1023744/body_surface_mesh.pt',
#   'old_id': 1664078,
#   'sex': 'female'},
#  '1023899': {'path': 'D:/ADLM Data/body_meshes/1023899/body_surface_mesh.pt',
#   'old_id': 1906959,
#   'sex': 'female'},
#  '1023915': {'path': 'D:/ADLM Data/body_meshes/1023915/body_surface_mesh.pt',
#   'old_id': 2239295,
#   'sex': 'male'},
#  '1024020': {'path': 'D:/ADLM Data/body_meshes/1024020/body_surface_mesh.pt',
#   'old_id': 3414219,
#   'sex': 'female'},
#  '1024158': {'path': 'D:/ADLM Data/body_meshes/1024158/body_surface_mesh.pt',
#   'old_id': 4877770,
#   'sex': 'female'},
#  '1024199': {'path': 'D:/ADLM Data/body_meshes/1024199/body_surface_mesh.pt',
#   'old_id': 4130686,
#   'sex': 'male'},
#  '1024257': {'path': 'D:/ADLM Data/body_meshes/1024257/body_surface_mesh.pt',
#   'old_id': 3802156,
#   'sex': 'female'},
#  '1024262': {'path': 'D:/ADLM Data/body_meshes/1024262/body_surface_mesh.pt',
#   'old_id': 2262006,
#   'sex': 'female'},
#  '1024270': {'path': 'D:/ADLM Data/body_meshes/1024270/body_surface_mesh.pt',
#   'old_id': 5404378,
#   'sex': 'female'},
#  '1024295': {'path': 'D:/ADLM Data/body_meshes/1024295/body_surface_mesh.pt',
#   'old_id': 1928422,
#   'sex': 'male'},
#  '1024335': {'path': 'D:/ADLM Data/body_meshes/1024335/body_surface_mesh.pt',
#   'old_id': 3873569,
#   'sex': 'male'},
#  '1024344': {'path': 'D:/ADLM Data/body_meshes/1024344/body_surface_mesh.pt',
#   'old_id': 4140610,
#   'sex': 'male'},
#  '1024387': {'path': 'D:/ADLM Data/body_meshes/1024387/body_surface_mesh.pt',
#   'old_id': 5408794,
#   'sex': 'female'},
#  '1024578': {'path': 'D:/ADLM Data/body_meshes/1024578/body_surface_mesh.pt',
#   'old_id': 4600101,
#   'sex': 'female'},
#  '1024823': {'path': 'D:/ADLM Data/body_meshes/1024823/body_surface_mesh.pt',
#   'old_id': 2745700,
#   'sex': 'female'},
#  '1024911': {'path': 'D:/ADLM Data/body_meshes/1024911/body_surface_mesh.pt',
#   'old_id': 2572293,
#   'sex': 'male'},
#  '1024989': {'path': 'D:/ADLM Data/body_meshes/1024989/body_surface_mesh.pt',
#   'old_id': 5353436,
#   'sex': 'female'},
#  '1025193': {'path': 'D:/ADLM Data/body_meshes/1025193/body_surface_mesh.pt',
#   'old_id': 3610435,
#   'sex': 'male'},
#  '1025334': {'path': 'D:/ADLM Data/body_meshes/1025334/body_surface_mesh.pt',
#   'old_id': 2334610,
#   'sex': 'male'},
#  '1025355': {'path': 'D:/ADLM Data/body_meshes/1025355/body_surface_mesh.pt',
#   'old_id': 1840595,
#   'sex': 'male'},
#  '1025381': {'path': 'D:/ADLM Data/body_meshes/1025381/body_surface_mesh.pt',
#   'old_id': 2317408,
#   'sex': 'female'},
#  '1025452': {'path': 'D:/ADLM Data/body_meshes/1025452/body_surface_mesh.pt',
#   'old_id': 4480274,
#   'sex': 'female'},
#  '1025509': {'path': 'D:/ADLM Data/body_meshes/1025509/body_surface_mesh.pt',
#   'old_id': 1510914,
#   'sex': 'female'},
#  '1025532': {'path': 'D:/ADLM Data/body_meshes/1025532/body_surface_mesh.pt',
#   'old_id': 3813683,
#   'sex': 'male'},
#  '1025723': {'path': 'D:/ADLM Data/body_meshes/1025723/body_surface_mesh.pt',
#   'old_id': 3522009,
#   'sex': 'male'},
#  '1025910': {'path': 'D:/ADLM Data/body_meshes/1025910/body_surface_mesh.pt',
#   'old_id': 5651596,
#   'sex': 'female'},
#  '1025945': {'path': 'D:/ADLM Data/body_meshes/1025945/body_surface_mesh.pt',
#   'old_id': 1432348,
#   'sex': 'male'},
#  '1026016': {'path': 'D:/ADLM Data/body_meshes/1026016/body_surface_mesh.pt',
#   'old_id': 5504362,
#   'sex': 'female'},
#  '1026266': {'path': 'D:/ADLM Data/body_meshes/1026266/body_surface_mesh.pt',
#   'old_id': 3499238,
#   'sex': 'female'},
#  '1026284': {'path': 'D:/ADLM Data/body_meshes/1026284/body_surface_mesh.pt',
#   'old_id': 5155127,
#   'sex': 'male'},
#  '1026589': {'path': 'D:/ADLM Data/body_meshes/1026589/body_surface_mesh.pt',
#   'old_id': 5405487,
#   'sex': 'male'},
#  '1026651': {'path': 'D:/ADLM Data/body_meshes/1026651/body_surface_mesh.pt',
#   'old_id': 5493665,
#   'sex': 'female'},
#  '1026987': {'path': 'D:/ADLM Data/body_meshes/1026987/body_surface_mesh.pt',
#   'old_id': 5261387,
#   'sex': 'female'},
#  '1027054': {'path': 'D:/ADLM Data/body_meshes/1027054/body_surface_mesh.pt',
#   'old_id': 2197417,
#   'sex': 'male'},
#  '1027164': {'path': 'D:/ADLM Data/body_meshes/1027164/body_surface_mesh.pt',
#   'old_id': 5957314,
#   'sex': 'female'},
#  '1027203': {'path': 'D:/ADLM Data/body_meshes/1027203/body_surface_mesh.pt',
#   'old_id': 5260481,
#   'sex': 'male'},
#  '1027275': {'path': 'D:/ADLM Data/body_meshes/1027275/body_surface_mesh.pt',
#   'old_id': 4193917,
#   'sex': 'male'},
#  '1027933': {'path': 'D:/ADLM Data/body_meshes/1027933/body_surface_mesh.pt',
#   'old_id': 2005450,
#   'sex': 'male'},
#  '1028117': {'path': 'D:/ADLM Data/body_meshes/1028117/body_surface_mesh.pt',
#   'old_id': 1723087,
#   'sex': 'female'},
#  '1028125': {'path': 'D:/ADLM Data/body_meshes/1028125/body_surface_mesh.pt',
#   'old_id': 5113650,
#   'sex': 'male'},
#  '1028132': {'path': 'D:/ADLM Data/body_meshes/1028132/body_surface_mesh.pt',
#   'old_id': 1722944,
#   'sex': 'male'},
#  '1028154': {'path': 'D:/ADLM Data/body_meshes/1028154/body_surface_mesh.pt',
#   'old_id': 2908003,
#   'sex': 'female'},
#  '1028180': {'path': 'D:/ADLM Data/body_meshes/1028180/body_surface_mesh.pt',
#   'old_id': 5074527,
#   'sex': 'female'},
#  '1028191': {'path': 'D:/ADLM Data/body_meshes/1028191/body_surface_mesh.pt',
#   'old_id': 1753031,
#   'sex': 'female'},
#  '1028298': {'path': 'D:/ADLM Data/body_meshes/1028298/body_surface_mesh.pt',
#   'old_id': 6006643,
#   'sex': 'female'},
#  '1028346': {'path': 'D:/ADLM Data/body_meshes/1028346/body_surface_mesh.pt',
#   'old_id': 3257347,
#   'sex': 'male'},
#  '1028487': {'path': 'D:/ADLM Data/body_meshes/1028487/body_surface_mesh.pt',
#   'old_id': 4302536,
#   'sex': 'female'},
#  '1028561': {'path': 'D:/ADLM Data/body_meshes/1028561/body_surface_mesh.pt',
#   'old_id': 2527037,
#   'sex': 'male'},
#  '1028631': {'path': 'D:/ADLM Data/body_meshes/1028631/body_surface_mesh.pt',
#   'old_id': 3683793,
#   'sex': 'female'},
#  '1028673': {'path': 'D:/ADLM Data/body_meshes/1028673/body_surface_mesh.pt',
#   'old_id': 3827039,
#   'sex': 'female'},
#  '1028684': {'path': 'D:/ADLM Data/body_meshes/1028684/body_surface_mesh.pt',
#   'old_id': 4640111,
#   'sex': 'female'},
#  '1028795': {'path': 'D:/ADLM Data/body_meshes/1028795/body_surface_mesh.pt',
#   'old_id': 2468553,
#   'sex': 'female'},
#  '1028955': {'path': 'D:/ADLM Data/body_meshes/1028955/body_surface_mesh.pt',
#   'old_id': 4269404,
#   'sex': 'male'},
#  '1028969': {'path': 'D:/ADLM Data/body_meshes/1028969/body_surface_mesh.pt',
#   'old_id': 3613172,
#   'sex': 'male'},
#  '1028978': {'path': 'D:/ADLM Data/body_meshes/1028978/body_surface_mesh.pt',
#   'old_id': 2189204,
#   'sex': 'female'},
#  '1028981': {'path': 'D:/ADLM Data/body_meshes/1028981/body_surface_mesh.pt',
#   'old_id': 5899772,
#   'sex': 'female'},
#  '1029035': {'path': 'D:/ADLM Data/body_meshes/1029035/body_surface_mesh.pt',
#   'old_id': 4976040,
#   'sex': 'female'},
#  '1029147': {'path': 'D:/ADLM Data/body_meshes/1029147/body_surface_mesh.pt',
#   'old_id': 3555324,
#   'sex': 'male'},
#  '1029255': {'path': 'D:/ADLM Data/body_meshes/1029255/body_surface_mesh.pt',
#   'old_id': 4246837,
#   'sex': 'male'},
#  '1029297': {'path': 'D:/ADLM Data/body_meshes/1029297/body_surface_mesh.pt',
#   'old_id': 3504049,
#   'sex': 'male'},
#  '1029488': {'path': 'D:/ADLM Data/body_meshes/1029488/body_surface_mesh.pt',
#   'old_id': 3150515,
#   'sex': 'male'},
#  '1029514': {'path': 'D:/ADLM Data/body_meshes/1029514/body_surface_mesh.pt',
#   'old_id': 1647167,
#   'sex': 'male'},
#  '1029557': {'path': 'D:/ADLM Data/body_meshes/1029557/body_surface_mesh.pt',
#   'old_id': 2205273,
#   'sex': 'male'},
#  '1029562': {'path': 'D:/ADLM Data/body_meshes/1029562/body_surface_mesh.pt',
#   'old_id': 5730664,
#   'sex': 'male'},
#  '1029745': {'path': 'D:/ADLM Data/body_meshes/1029745/body_surface_mesh.pt',
#   'old_id': 5207993,
#   'sex': 'male'},
#  '1029783': {'path': 'D:/ADLM Data/body_meshes/1029783/body_surface_mesh.pt',
#   'old_id': 2729025,
#   'sex': 'male'},
#  '1029803': {'path': 'D:/ADLM Data/body_meshes/1029803/body_surface_mesh.pt',
#   'old_id': 4647381,
#   'sex': 'female'},
#  '1029846': {'path': 'D:/ADLM Data/body_meshes/1029846/body_surface_mesh.pt',
#   'old_id': 2441134,
#   'sex': 'female'},
#  '1030232': {'path': 'D:/ADLM Data/body_meshes/1030232/body_surface_mesh.pt',
#   'old_id': 3156715,
#   'sex': 'female'},
#  '1030276': {'path': 'D:/ADLM Data/body_meshes/1030276/body_surface_mesh.pt',
#   'old_id': 1011375,
#   'sex': 'male'},
#  '1030350': {'path': 'D:/ADLM Data/body_meshes/1030350/body_surface_mesh.pt',
#   'old_id': 1391253,
#   'sex': 'male'},
#  '1030384': {'path': 'D:/ADLM Data/body_meshes/1030384/body_surface_mesh.pt',
#   'old_id': 5898014,
#   'sex': 'female'},
#  '1030874': {'path': 'D:/ADLM Data/body_meshes/1030874/body_surface_mesh.pt',
#   'old_id': 5450959,
#   'sex': 'male'},
#  '1030939': {'path': 'D:/ADLM Data/body_meshes/1030939/body_surface_mesh.pt',
#   'old_id': 4510256,
#   'sex': 'female'},
#  '1030940': {'path': 'D:/ADLM Data/body_meshes/1030940/body_surface_mesh.pt',
#   'old_id': 1531098,
#   'sex': 'female'},
#  '1031019': {'path': 'D:/ADLM Data/body_meshes/1031019/body_surface_mesh.pt',
#   'old_id': 3238607,
#   'sex': 'male'},
#  '1031234': {'path': 'D:/ADLM Data/body_meshes/1031234/body_surface_mesh.pt',
#   'old_id': 3398420,
#   'sex': 'female'},
#  '1031632': {'path': 'D:/ADLM Data/body_meshes/1031632/body_surface_mesh.pt',
#   'old_id': 5777621,
#   'sex': 'female'},
#  '1031648': {'path': 'D:/ADLM Data/body_meshes/1031648/body_surface_mesh.pt',
#   'old_id': 3777897,
#   'sex': 'female'},
#  '1031736': {'path': 'D:/ADLM Data/body_meshes/1031736/body_surface_mesh.pt',
#   'old_id': 4205597,
#   'sex': 'male'},
#  '1031846': {'path': 'D:/ADLM Data/body_meshes/1031846/body_surface_mesh.pt',
#   'old_id': 5371763,
#   'sex': 'male'},
#  '1031875': {'path': 'D:/ADLM Data/body_meshes/1031875/body_surface_mesh.pt',
#   'old_id': 2023601,
#   'sex': 'female'},
#  '1031923': {'path': 'D:/ADLM Data/body_meshes/1031923/body_surface_mesh.pt',
#   'old_id': 3813699,
#   'sex': 'male'},
#  '1031998': {'path': 'D:/ADLM Data/body_meshes/1031998/body_surface_mesh.pt',
#   'old_id': 4018118,
#   'sex': 'male'},
#  '1032101': {'path': 'D:/ADLM Data/body_meshes/1032101/body_surface_mesh.pt',
#   'old_id': 3122848,
#   'sex': 'male'},
#  '1032279': {'path': 'D:/ADLM Data/body_meshes/1032279/body_surface_mesh.pt',
#   'old_id': 4191589,
#   'sex': 'female'},
#  '1032438': {'path': 'D:/ADLM Data/body_meshes/1032438/body_surface_mesh.pt',
#   'old_id': 4863179,
#   'sex': 'male'},
#  '1032591': {'path': 'D:/ADLM Data/body_meshes/1032591/body_surface_mesh.pt',
#   'old_id': 4695567,
#   'sex': 'male'},
#  '1032608': {'path': 'D:/ADLM Data/body_meshes/1032608/body_surface_mesh.pt',
#   'old_id': 2330694,
#   'sex': 'male'},
#  '1032723': {'path': 'D:/ADLM Data/body_meshes/1032723/body_surface_mesh.pt',
#   'old_id': 4405663,
#   'sex': 'male'},
#  '1032777': {'path': 'D:/ADLM Data/body_meshes/1032777/body_surface_mesh.pt',
#   'old_id': 5978711,
#   'sex': 'female'},
#  '1032871': {'path': 'D:/ADLM Data/body_meshes/1032871/body_surface_mesh.pt',
#   'old_id': 2380692,
#   'sex': 'male'},
#  '1033003': {'path': 'D:/ADLM Data/body_meshes/1033003/body_surface_mesh.pt',
#   'old_id': 1552352,
#   'sex': 'female'},
#  '1033186': {'path': 'D:/ADLM Data/body_meshes/1033186/body_surface_mesh.pt',
#   'old_id': 4141514,
#   'sex': 'male'},
#  '1033274': {'path': 'D:/ADLM Data/body_meshes/1033274/body_surface_mesh.pt',
#   'old_id': 2727663,
#   'sex': 'male'},
#  '1033353': {'path': 'D:/ADLM Data/body_meshes/1033353/body_surface_mesh.pt',
#   'old_id': 1972538,
#   'sex': 'female'},
#  '1033484': {'path': 'D:/ADLM Data/body_meshes/1033484/body_surface_mesh.pt',
#   'old_id': 4680541,
#   'sex': 'male'},
#  '1033559': {'path': 'D:/ADLM Data/body_meshes/1033559/body_surface_mesh.pt',
#   'old_id': 1842073,
#   'sex': 'male'},
#  '1033582': {'path': 'D:/ADLM Data/body_meshes/1033582/body_surface_mesh.pt',
#   'old_id': 5614723,
#   'sex': 'male'},
#  '1033672': {'path': 'D:/ADLM Data/body_meshes/1033672/body_surface_mesh.pt',
#   'old_id': 4838245,
#   'sex': 'male'},
#  '1033717': {'path': 'D:/ADLM Data/body_meshes/1033717/body_surface_mesh.pt',
#   'old_id': 3013338,
#   'sex': 'female'},
#  '1034178': {'path': 'D:/ADLM Data/body_meshes/1034178/body_surface_mesh.pt',
#   'old_id': 3986193,
#   'sex': 'male'},
#  '1034309': {'path': 'D:/ADLM Data/body_meshes/1034309/body_surface_mesh.pt',
#   'old_id': 3695493,
#   'sex': 'male'},
#  '1034354': {'path': 'D:/ADLM Data/body_meshes/1034354/body_surface_mesh.pt',
#   'old_id': 4312958,
#   'sex': 'male'},
#  '1034461': {'path': 'D:/ADLM Data/body_meshes/1034461/body_surface_mesh.pt',
#   'old_id': 5221803,
#   'sex': 'female'},
#  '1034503': {'path': 'D:/ADLM Data/body_meshes/1034503/body_surface_mesh.pt',
#   'old_id': 4207242,
#   'sex': 'female'},
#  '1034552': {'path': 'D:/ADLM Data/body_meshes/1034552/body_surface_mesh.pt',
#   'old_id': 2282238,
#   'sex': 'female'},
#  '1034620': {'path': 'D:/ADLM Data/body_meshes/1034620/body_surface_mesh.pt',
#   'old_id': 4691430,
#   'sex': 'female'},
#  '1034685': {'path': 'D:/ADLM Data/body_meshes/1034685/body_surface_mesh.pt',
#   'old_id': 2325429,
#   'sex': 'female'},
#  '1034715': {'path': 'D:/ADLM Data/body_meshes/1034715/body_surface_mesh.pt',
#   'old_id': 4009378,
#   'sex': 'male'},
#  '1034764': {'path': 'D:/ADLM Data/body_meshes/1034764/body_surface_mesh.pt',
#   'old_id': 2273895,
#   'sex': 'female'},
#  '1034833': {'path': 'D:/ADLM Data/body_meshes/1034833/body_surface_mesh.pt',
#   'old_id': 1661708,
#   'sex': 'male'},
#  '1035204': {'path': 'D:/ADLM Data/body_meshes/1035204/body_surface_mesh.pt',
#   'old_id': 1818411,
#   'sex': 'female'},
#  '1035265': {'path': 'D:/ADLM Data/body_meshes/1035265/body_surface_mesh.pt',
#   'old_id': 4755115,
#   'sex': 'female'},
#  '1035460': {'path': 'D:/ADLM Data/body_meshes/1035460/body_surface_mesh.pt',
#   'old_id': 4188703,
#   'sex': 'female'},
#  '1035733': {'path': 'D:/ADLM Data/body_meshes/1035733/body_surface_mesh.pt',
#   'old_id': 5769166,
#   'sex': 'female'},
#  '1035879': {'path': 'D:/ADLM Data/body_meshes/1035879/body_surface_mesh.pt',
#   'old_id': 3322855,
#   'sex': 'male'},
#  '1036033': {'path': 'D:/ADLM Data/body_meshes/1036033/body_surface_mesh.pt',
#   'old_id': 2492126,
#   'sex': 'female'},
#  '1036189': {'path': 'D:/ADLM Data/body_meshes/1036189/body_surface_mesh.pt',
#   'old_id': 4475955,
#   'sex': 'female'},
#  '1036227': {'path': 'D:/ADLM Data/body_meshes/1036227/body_surface_mesh.pt',
#   'old_id': 3582793,
#   'sex': 'male'},
#  '1036264': {'path': 'D:/ADLM Data/body_meshes/1036264/body_surface_mesh.pt',
#   'old_id': 4305286,
#   'sex': 'male'},
#  '1036383': {'path': 'D:/ADLM Data/body_meshes/1036383/body_surface_mesh.pt',
#   'old_id': 3510632,
#   'sex': 'female'},
#  '1036519': {'path': 'D:/ADLM Data/body_meshes/1036519/body_surface_mesh.pt',
#   'old_id': 3135883,
#   'sex': 'male'},
#  '1036682': {'path': 'D:/ADLM Data/body_meshes/1036682/body_surface_mesh.pt',
#   'old_id': 3362381,
#   'sex': 'male'},
#  '1036909': {'path': 'D:/ADLM Data/body_meshes/1036909/body_surface_mesh.pt',
#   'old_id': 1369732,
#   'sex': 'female'},
#  '1036932': {'path': 'D:/ADLM Data/body_meshes/1036932/body_surface_mesh.pt',
#   'old_id': 2647040,
#   'sex': 'female'},
#  '1037010': {'path': 'D:/ADLM Data/body_meshes/1037010/body_surface_mesh.pt',
#   'old_id': 1377469,
#   'sex': 'female'},
#  '1037120': {'path': 'D:/ADLM Data/body_meshes/1037120/body_surface_mesh.pt',
#   'old_id': 2327620,
#   'sex': 'male'},
#  '1037151': {'path': 'D:/ADLM Data/body_meshes/1037151/body_surface_mesh.pt',
#   'old_id': 5148728,
#   'sex': 'female'},
#  '1037201': {'path': 'D:/ADLM Data/body_meshes/1037201/body_surface_mesh.pt',
#   'old_id': 1524914,
#   'sex': 'male'},
#  '1037244': {'path': 'D:/ADLM Data/body_meshes/1037244/body_surface_mesh.pt',
#   'old_id': 5050754,
#   'sex': 'male'},
#  '1037256': {'path': 'D:/ADLM Data/body_meshes/1037256/body_surface_mesh.pt',
#   'old_id': 3495829,
#   'sex': 'male'},
#  '1037287': {'path': 'D:/ADLM Data/body_meshes/1037287/body_surface_mesh.pt',
#   'old_id': 2268729,
#   'sex': 'female'},
#  '1037370': {'path': 'D:/ADLM Data/body_meshes/1037370/body_surface_mesh.pt',
#   'old_id': 1143203,
#   'sex': 'male'},
#  '1037527': {'path': 'D:/ADLM Data/body_meshes/1037527/body_surface_mesh.pt',
#   'old_id': 5396262,
#   'sex': 'male'},
#  '1037564': {'path': 'D:/ADLM Data/body_meshes/1037564/body_surface_mesh.pt',
#   'old_id': 2686259,
#   'sex': 'female'},
#  '1037724': {'path': 'D:/ADLM Data/body_meshes/1037724/body_surface_mesh.pt',
#   'old_id': 5384798,
#   'sex': 'male'},
#  '1037790': {'path': 'D:/ADLM Data/body_meshes/1037790/body_surface_mesh.pt',
#   'old_id': 3989293,
#   'sex': 'female'},
#  '1037809': {'path': 'D:/ADLM Data/body_meshes/1037809/body_surface_mesh.pt',
#   'old_id': 5096844,
#   'sex': 'female'},
#  '1037854': {'path': 'D:/ADLM Data/body_meshes/1037854/body_surface_mesh.pt',
#   'old_id': 2317781,
#   'sex': 'female'},
#  '1037929': {'path': 'D:/ADLM Data/body_meshes/1037929/body_surface_mesh.pt',
#   'old_id': 3351856,
#   'sex': 'female'},
#  '1038051': {'path': 'D:/ADLM Data/body_meshes/1038051/body_surface_mesh.pt',
#   'old_id': 2911911,
#   'sex': 'female'},
#  '1038122': {'path': 'D:/ADLM Data/body_meshes/1038122/body_surface_mesh.pt',
#   'old_id': 3784259,
#   'sex': 'male'},
#  '1038233': {'path': 'D:/ADLM Data/body_meshes/1038233/body_surface_mesh.pt',
#   'old_id': 3195533,
#   'sex': 'male'},
#  '1038301': {'path': 'D:/ADLM Data/body_meshes/1038301/body_surface_mesh.pt',
#   'old_id': 1758260,
#   'sex': 'female'},
#  '1038417': {'path': 'D:/ADLM Data/body_meshes/1038417/body_surface_mesh.pt',
#   'old_id': 5933668,
#   'sex': 'female'},
#  '1038578': {'path': 'D:/ADLM Data/body_meshes/1038578/body_surface_mesh.pt',
#   'old_id': 4676743,
#   'sex': 'female'},
#  '1038602': {'path': 'D:/ADLM Data/body_meshes/1038602/body_surface_mesh.pt',
#   'old_id': 1113693,
#   'sex': 'female'},
#  '1038640': {'path': 'D:/ADLM Data/body_meshes/1038640/body_surface_mesh.pt',
#   'old_id': 2436706,
#   'sex': 'female'},
#  '1038731': {'path': 'D:/ADLM Data/body_meshes/1038731/body_surface_mesh.pt',
#   'old_id': 5513718,
#   'sex': 'male'},
#  '1038938': {'path': 'D:/ADLM Data/body_meshes/1038938/body_surface_mesh.pt',
#   'old_id': 5409801,
#   'sex': 'female'},
#  '1039164': {'path': 'D:/ADLM Data/body_meshes/1039164/body_surface_mesh.pt',
#   'old_id': 3234634,
#   'sex': 'female'},
#  '1039171': {'path': 'D:/ADLM Data/body_meshes/1039171/body_surface_mesh.pt',
#   'old_id': 4221510,
#   'sex': 'male'},
#  '1039377': {'path': 'D:/ADLM Data/body_meshes/1039377/body_surface_mesh.pt',
#   'old_id': 3967156,
#   'sex': 'female'},
#  '1039451': {'path': 'D:/ADLM Data/body_meshes/1039451/body_surface_mesh.pt',
#   'old_id': 5348592,
#   'sex': 'female'},
#  '1039781': {'path': 'D:/ADLM Data/body_meshes/1039781/body_surface_mesh.pt',
#   'old_id': 5376620,
#   'sex': 'male'},
#  '1039819': {'path': 'D:/ADLM Data/body_meshes/1039819/body_surface_mesh.pt',
#   'old_id': 5671886,
#   'sex': 'female'},
#  '1040160': {'path': 'D:/ADLM Data/body_meshes/1040160/body_surface_mesh.pt',
#   'old_id': 5779733,
#   'sex': 'female'},
#  '1040397': {'path': 'D:/ADLM Data/body_meshes/1040397/body_surface_mesh.pt',
#   'old_id': 4340373,
#   'sex': 'male'},
#  '1040532': {'path': 'D:/ADLM Data/body_meshes/1040532/body_surface_mesh.pt',
#   'old_id': 2330629,
#   'sex': 'female'},
#  '1040961': {'path': 'D:/ADLM Data/body_meshes/1040961/body_surface_mesh.pt',
#   'old_id': 5968493,
#   'sex': 'male'},
#  '1041059': {'path': 'D:/ADLM Data/body_meshes/1041059/body_surface_mesh.pt',
#   'old_id': 3747682,
#   'sex': 'male'},
#  '1041422': {'path': 'D:/ADLM Data/body_meshes/1041422/body_surface_mesh.pt',
#   'old_id': 5124345,
#   'sex': 'male'},
#  '1041524': {'path': 'D:/ADLM Data/body_meshes/1041524/body_surface_mesh.pt',
#   'old_id': 2532347,
#   'sex': 'female'},
#  '1041546': {'path': 'D:/ADLM Data/body_meshes/1041546/body_surface_mesh.pt',
#   'old_id': 5328545,
#   'sex': 'female'},
#  '1041715': {'path': 'D:/ADLM Data/body_meshes/1041715/body_surface_mesh.pt',
#   'old_id': 1352160,
#   'sex': 'female'},
#  '1041727': {'path': 'D:/ADLM Data/body_meshes/1041727/body_surface_mesh.pt',
#   'old_id': 4450390,
#   'sex': 'female'},
#  '1041788': {'path': 'D:/ADLM Data/body_meshes/1041788/body_surface_mesh.pt',
#   'old_id': 5818977,
#   'sex': 'male'},
#  '1041849': {'path': 'D:/ADLM Data/body_meshes/1041849/body_surface_mesh.pt',
#   'old_id': 5389198,
#   'sex': 'female'},
#  '1041944': {'path': 'D:/ADLM Data/body_meshes/1041944/body_surface_mesh.pt',
#   'old_id': 4736989,
#   'sex': 'male'},
#  '1042000': {'path': 'D:/ADLM Data/body_meshes/1042000/body_surface_mesh.pt',
#   'old_id': 2318474,
#   'sex': 'male'},
#  '1042069': {'path': 'D:/ADLM Data/body_meshes/1042069/body_surface_mesh.pt',
#   'old_id': 4984422,
#   'sex': 'male'},
#  '1042232': {'path': 'D:/ADLM Data/body_meshes/1042232/body_surface_mesh.pt',
#   'old_id': 5306537,
#   'sex': 'female'},
#  '1042329': {'path': 'D:/ADLM Data/body_meshes/1042329/body_surface_mesh.pt',
#   'old_id': 5938394,
#   'sex': 'female'},
#  '1042392': {'path': 'D:/ADLM Data/body_meshes/1042392/body_surface_mesh.pt',
#   'old_id': 4579467,
#   'sex': 'male'},
#  '1042594': {'path': 'D:/ADLM Data/body_meshes/1042594/body_surface_mesh.pt',
#   'old_id': 3185957,
#   'sex': 'female'},
#  '1042675': {'path': 'D:/ADLM Data/body_meshes/1042675/body_surface_mesh.pt',
#   'old_id': 4527538,
#   'sex': 'female'},
#  '1042793': {'path': 'D:/ADLM Data/body_meshes/1042793/body_surface_mesh.pt',
#   'old_id': 5824310,
#   'sex': 'male'},
#  '1042822': {'path': 'D:/ADLM Data/body_meshes/1042822/body_surface_mesh.pt',
#   'old_id': 3450216,
#   'sex': 'female'},
#  '1043021': {'path': 'D:/ADLM Data/body_meshes/1043021/body_surface_mesh.pt',
#   'old_id': 4558967,
#   'sex': 'male'},
#  '1043111': {'path': 'D:/ADLM Data/body_meshes/1043111/body_surface_mesh.pt',
#   'old_id': 4287487,
#   'sex': 'female'},
#  '1043167': {'path': 'D:/ADLM Data/body_meshes/1043167/body_surface_mesh.pt',
#   'old_id': 3798493,
#   'sex': 'male'},
#  '1043296': {'path': 'D:/ADLM Data/body_meshes/1043296/body_surface_mesh.pt',
#   'old_id': 1382213,
#   'sex': 'male'},
#  '1043322': {'path': 'D:/ADLM Data/body_meshes/1043322/body_surface_mesh.pt',
#   'old_id': 2054416,
#   'sex': 'female'},
#  '1043455': {'path': 'D:/ADLM Data/body_meshes/1043455/body_surface_mesh.pt',
#   'old_id': 3021151,
#   'sex': 'female'},
#  '1043544': {'path': 'D:/ADLM Data/body_meshes/1043544/body_surface_mesh.pt',
#   'old_id': 3233605,
#   'sex': 'male'},
#  '1043560': {'path': 'D:/ADLM Data/body_meshes/1043560/body_surface_mesh.pt',
#   'old_id': 1365270,
#   'sex': 'male'},
#  '1043593': {'path': 'D:/ADLM Data/body_meshes/1043593/body_surface_mesh.pt',
#   'old_id': 4581031,
#   'sex': 'male'},
#  '1043682': {'path': 'D:/ADLM Data/body_meshes/1043682/body_surface_mesh.pt',
#   'old_id': 2916701,
#   'sex': 'female'},
#  '1043831': {'path': 'D:/ADLM Data/body_meshes/1043831/body_surface_mesh.pt',
#   'old_id': 4869693,
#   'sex': 'female'},
#  '1043847': {'path': 'D:/ADLM Data/body_meshes/1043847/body_surface_mesh.pt',
#   'old_id': 2919879,
#   'sex': 'male'},
#  '1043948': {'path': 'D:/ADLM Data/body_meshes/1043948/body_surface_mesh.pt',
#   'old_id': 5999436,
#   'sex': 'male'},
#  '1043954': {'path': 'D:/ADLM Data/body_meshes/1043954/body_surface_mesh.pt',
#   'old_id': 3340377,
#   'sex': 'male'},
#  '1044028': {'path': 'D:/ADLM Data/body_meshes/1044028/body_surface_mesh.pt',
#   'old_id': 2996831,
#   'sex': 'male'},
#  '1044147': {'path': 'D:/ADLM Data/body_meshes/1044147/body_surface_mesh.pt',
#   'old_id': 1066822,
#   'sex': 'male'},
#  '1044508': {'path': 'D:/ADLM Data/body_meshes/1044508/body_surface_mesh.pt',
#   'old_id': 3591409,
#   'sex': 'female'},
#  '1044722': {'path': 'D:/ADLM Data/body_meshes/1044722/body_surface_mesh.pt',
#   'old_id': 1373426,
#   'sex': 'female'},
#  '1044758': {'path': 'D:/ADLM Data/body_meshes/1044758/body_surface_mesh.pt',
#   'old_id': 5991884,
#   'sex': 'female'},
#  '1044867': {'path': 'D:/ADLM Data/body_meshes/1044867/body_surface_mesh.pt',
#   'old_id': 5184101,
#   'sex': 'male'},
#  '1044977': {'path': 'D:/ADLM Data/body_meshes/1044977/body_surface_mesh.pt',
#   'old_id': 5541138,
#   'sex': 'female'},
#  '1045201': {'path': 'D:/ADLM Data/body_meshes/1045201/body_surface_mesh.pt',
#   'old_id': 1058622,
#   'sex': 'female'},
#  '1045272': {'path': 'D:/ADLM Data/body_meshes/1045272/body_surface_mesh.pt',
# ...
#   'old_id': 4877808,
#   'sex': 'female'},
#  '1097774': {'path': 'D:/ADLM Data/body_meshes/1097774/body_surface_mesh.pt',
#   'old_id': 4486059,
#   'sex': 'female'},
#  '1097890': {'path': 'D:/ADLM Data/body_meshes/1097890/body_surface_mesh.pt',
#   'old_id': 2246500,
#   'sex': 'female'},
#  '1097930': {'path': 'D:/ADLM Data/body_meshes/1097930/body_surface_mesh.pt',
#   'old_id': 3513102,
#   'sex': 'male'},
#  '1098031': {'path': 'D:/ADLM Data/body_meshes/1098031/body_surface_mesh.pt',
#   'old_id': 3828661,
#   'sex': 'male'},
#  '1098300': {'path': 'D:/ADLM Data/body_meshes/1098300/body_surface_mesh.pt',
#   'old_id': 5338534,
#   'sex': 'male'},
#  '1098326': {'path': 'D:/ADLM Data/body_meshes/1098326/body_surface_mesh.pt',
#   'old_id': 1398669,
#   'sex': 'male'},
#  '1098591': {'path': 'D:/ADLM Data/body_meshes/1098591/body_surface_mesh.pt',
#   'old_id': 3101150,
#   'sex': 'male'},
#  '1098716': {'path': 'D:/ADLM Data/body_meshes/1098716/body_surface_mesh.pt',
#   'old_id': 3726216,
#   'sex': 'male'},
#  '1098827': {'path': 'D:/ADLM Data/body_meshes/1098827/body_surface_mesh.pt',
#   'old_id': 1667830,
#   'sex': 'male'},
#  '1098936': {'path': 'D:/ADLM Data/body_meshes/1098936/body_surface_mesh.pt',
#   'old_id': 5133252,
#   'sex': 'female'},
#  '1098958': {'path': 'D:/ADLM Data/body_meshes/1098958/body_surface_mesh.pt',
#   'old_id': 2673799,
#   'sex': 'male'},
#  '1098999': {'path': 'D:/ADLM Data/body_meshes/1098999/body_surface_mesh.pt',
#   'old_id': 2656701,
#   'sex': 'female'},
#  '1099133': {'path': 'D:/ADLM Data/body_meshes/1099133/body_surface_mesh.pt',
#   'old_id': 5625245,
#   'sex': 'male'},
#  '1099157': {'path': 'D:/ADLM Data/body_meshes/1099157/body_surface_mesh.pt',
#   'old_id': 3416624,
#   'sex': 'female'},
#  '1099210': {'path': 'D:/ADLM Data/body_meshes/1099210/body_surface_mesh.pt',
#   'old_id': 2828340,
#   'sex': 'female'},
#  '1099473': {'path': 'D:/ADLM Data/body_meshes/1099473/body_surface_mesh.pt',
#   'old_id': 4601864,
#   'sex': 'male'},
#  '1099559': {'path': 'D:/ADLM Data/body_meshes/1099559/body_surface_mesh.pt',
#   'old_id': 1291552,
#   'sex': 'female'},
#  '1099635': {'path': 'D:/ADLM Data/body_meshes/1099635/body_surface_mesh.pt',
#   'old_id': 4522514,
#   'sex': 'female'},
#  '1099878': {'path': 'D:/ADLM Data/body_meshes/1099878/body_surface_mesh.pt',
#   'old_id': 3954998,
#   'sex': 'female'},
#  '1099906': {'path': 'D:/ADLM Data/body_meshes/1099906/body_surface_mesh.pt',
#   'old_id': 1571313,
#   'sex': 'male'},
#  '1100173': {'path': 'D:/ADLM Data/body_meshes/1100173/body_surface_mesh.pt',
#   'old_id': 2364770,
#   'sex': 'male'},
#  '1100226': {'path': 'D:/ADLM Data/body_meshes/1100226/body_surface_mesh.pt',
#   'old_id': 5437202,
#   'sex': 'male'},
#  '1100368': {'path': 'D:/ADLM Data/body_meshes/1100368/body_surface_mesh.pt',
#   'old_id': 2114865,
#   'sex': 'female'},
#  '1100890': {'path': 'D:/ADLM Data/body_meshes/1100890/body_surface_mesh.pt',
#   'old_id': 1906848,
#   'sex': 'male'},
#  '1101007': {'path': 'D:/ADLM Data/body_meshes/1101007/body_surface_mesh.pt',
#   'old_id': 5191209,
#   'sex': 'male'},
#  '1101441': {'path': 'D:/ADLM Data/body_meshes/1101441/body_surface_mesh.pt',
#   'old_id': 5278324,
#   'sex': 'male'},
#  '1101459': {'path': 'D:/ADLM Data/body_meshes/1101459/body_surface_mesh.pt',
#   'old_id': 1869807,
#   'sex': 'female'},
#  '1101515': {'path': 'D:/ADLM Data/body_meshes/1101515/body_surface_mesh.pt',
#   'old_id': 1863305,
#   'sex': 'female'},
#  '1101571': {'path': 'D:/ADLM Data/body_meshes/1101571/body_surface_mesh.pt',
#   'old_id': 2616713,
#   'sex': 'male'},
#  '1101681': {'path': 'D:/ADLM Data/body_meshes/1101681/body_surface_mesh.pt',
#   'old_id': 4665800,
#   'sex': 'female'},
#  '1102094': {'path': 'D:/ADLM Data/body_meshes/1102094/body_surface_mesh.pt',
#   'old_id': 1892966,
#   'sex': 'male'},
#  '1102145': {'path': 'D:/ADLM Data/body_meshes/1102145/body_surface_mesh.pt',
#   'old_id': 5653468,
#   'sex': 'female'},
#  '1102161': {'path': 'D:/ADLM Data/body_meshes/1102161/body_surface_mesh.pt',
#   'old_id': 3657528,
#   'sex': 'male'},
#  '1102183': {'path': 'D:/ADLM Data/body_meshes/1102183/body_surface_mesh.pt',
#   'old_id': 2806670,
#   'sex': 'male'},
#  '1102360': {'path': 'D:/ADLM Data/body_meshes/1102360/body_surface_mesh.pt',
#   'old_id': 1445998,
#   'sex': 'female'},
#  '1102425': {'path': 'D:/ADLM Data/body_meshes/1102425/body_surface_mesh.pt',
#   'old_id': 3061400,
#   'sex': 'male'},
#  '1102534': {'path': 'D:/ADLM Data/body_meshes/1102534/body_surface_mesh.pt',
#   'old_id': 4361565,
#   'sex': 'male'},
#  '1102555': {'path': 'D:/ADLM Data/body_meshes/1102555/body_surface_mesh.pt',
#   'old_id': 1368005,
#   'sex': 'male'},
#  '1102581': {'path': 'D:/ADLM Data/body_meshes/1102581/body_surface_mesh.pt',
#   'old_id': 1132185,
#   'sex': 'female'},
#  '1102597': {'path': 'D:/ADLM Data/body_meshes/1102597/body_surface_mesh.pt',
#   'old_id': 2843675,
#   'sex': 'female'},
#  '1102804': {'path': 'D:/ADLM Data/body_meshes/1102804/body_surface_mesh.pt',
#   'old_id': 3208117,
#   'sex': 'male'},
#  '1103140': {'path': 'D:/ADLM Data/body_meshes/1103140/body_surface_mesh.pt',
#   'old_id': 2277614,
#   'sex': 'male'},
#  '1103275': {'path': 'D:/ADLM Data/body_meshes/1103275/body_surface_mesh.pt',
#   'old_id': 1007218,
#   'sex': 'male'},
#  '1103412': {'path': 'D:/ADLM Data/body_meshes/1103412/body_surface_mesh.pt',
#   'old_id': 1940369,
#   'sex': 'female'},
#  '1103592': {'path': 'D:/ADLM Data/body_meshes/1103592/body_surface_mesh.pt',
#   'old_id': 4579031,
#   'sex': 'male'},
#  '1103797': {'path': 'D:/ADLM Data/body_meshes/1103797/body_surface_mesh.pt',
#   'old_id': 4433822,
#   'sex': 'female'},
#  '1103844': {'path': 'D:/ADLM Data/body_meshes/1103844/body_surface_mesh.pt',
#   'old_id': 4305369,
#   'sex': 'male'},
#  '1103949': {'path': 'D:/ADLM Data/body_meshes/1103949/body_surface_mesh.pt',
#   'old_id': 1574396,
#   'sex': 'male'},
#  '1103957': {'path': 'D:/ADLM Data/body_meshes/1103957/body_surface_mesh.pt',
#   'old_id': 5151110,
#   'sex': 'female'},
#  '1103962': {'path': 'D:/ADLM Data/body_meshes/1103962/body_surface_mesh.pt',
#   'old_id': 1681634,
#   'sex': 'female'},
#  '1104135': {'path': 'D:/ADLM Data/body_meshes/1104135/body_surface_mesh.pt',
#   'old_id': 5140602,
#   'sex': 'male'},
#  '1104206': {'path': 'D:/ADLM Data/body_meshes/1104206/body_surface_mesh.pt',
#   'old_id': 1829771,
#   'sex': 'female'},
#  '1104212': {'path': 'D:/ADLM Data/body_meshes/1104212/body_surface_mesh.pt',
#   'old_id': 1136531,
#   'sex': 'female'},
#  '1104452': {'path': 'D:/ADLM Data/body_meshes/1104452/body_surface_mesh.pt',
#   'old_id': 5772571,
#   'sex': 'male'},
#  '1104554': {'path': 'D:/ADLM Data/body_meshes/1104554/body_surface_mesh.pt',
#   'old_id': 2486868,
#   'sex': 'female'},
#  '1104704': {'path': 'D:/ADLM Data/body_meshes/1104704/body_surface_mesh.pt',
#   'old_id': 1277935,
#   'sex': 'male'},
#  '1104759': {'path': 'D:/ADLM Data/body_meshes/1104759/body_surface_mesh.pt',
#   'old_id': 1657960,
#   'sex': 'male'},
#  '1104896': {'path': 'D:/ADLM Data/body_meshes/1104896/body_surface_mesh.pt',
#   'old_id': 2305142,
#   'sex': 'female'},
#  '1105205': {'path': 'D:/ADLM Data/body_meshes/1105205/body_surface_mesh.pt',
#   'old_id': 4488419,
#   'sex': 'female'},
#  '1105273': {'path': 'D:/ADLM Data/body_meshes/1105273/body_surface_mesh.pt',
#   'old_id': 4538783,
#   'sex': 'female'},
#  '1105612': {'path': 'D:/ADLM Data/body_meshes/1105612/body_surface_mesh.pt',
#   'old_id': 5726549,
#   'sex': 'female'},
#  '1105796': {'path': 'D:/ADLM Data/body_meshes/1105796/body_surface_mesh.pt',
#   'old_id': 1329976,
#   'sex': 'female'},
#  '1105919': {'path': 'D:/ADLM Data/body_meshes/1105919/body_surface_mesh.pt',
#   'old_id': 5087014,
#   'sex': 'male'},
#  '1106053': {'path': 'D:/ADLM Data/body_meshes/1106053/body_surface_mesh.pt',
#   'old_id': 5110417,
#   'sex': 'female'},
#  '1106109': {'path': 'D:/ADLM Data/body_meshes/1106109/body_surface_mesh.pt',
#   'old_id': 5885910,
#   'sex': 'female'},
#  '1106180': {'path': 'D:/ADLM Data/body_meshes/1106180/body_surface_mesh.pt',
#   'old_id': 2443020,
#   'sex': 'male'},
#  '1106969': {'path': 'D:/ADLM Data/body_meshes/1106969/body_surface_mesh.pt',
#   'old_id': 2986614,
#   'sex': 'female'},
#  '1107114': {'path': 'D:/ADLM Data/body_meshes/1107114/body_surface_mesh.pt',
#   'old_id': 2951618,
#   'sex': 'female'},
#  '1107121': {'path': 'D:/ADLM Data/body_meshes/1107121/body_surface_mesh.pt',
#   'old_id': 4098898,
#   'sex': 'male'},
#  '1107236': {'path': 'D:/ADLM Data/body_meshes/1107236/body_surface_mesh.pt',
#   'old_id': 2157007,
#   'sex': 'male'},
#  '1107405': {'path': 'D:/ADLM Data/body_meshes/1107405/body_surface_mesh.pt',
#   'old_id': 2273650,
#   'sex': 'male'},
#  '1107431': {'path': 'D:/ADLM Data/body_meshes/1107431/body_surface_mesh.pt',
#   'old_id': 5336138,
#   'sex': 'male'},
#  '1107530': {'path': 'D:/ADLM Data/body_meshes/1107530/body_surface_mesh.pt',
#   'old_id': 1233670,
#   'sex': 'male'},
#  '1107582': {'path': 'D:/ADLM Data/body_meshes/1107582/body_surface_mesh.pt',
#   'old_id': 2777441,
#   'sex': 'female'},
#  '1107601': {'path': 'D:/ADLM Data/body_meshes/1107601/body_surface_mesh.pt',
#   'old_id': 1359443,
#   'sex': 'male'},
#  '1107813': {'path': 'D:/ADLM Data/body_meshes/1107813/body_surface_mesh.pt',
#   'old_id': 2024005,
#   'sex': 'female'},
#  '1107869': {'path': 'D:/ADLM Data/body_meshes/1107869/body_surface_mesh.pt',
#   'old_id': 2126261,
#   'sex': 'female'},
#  '1107906': {'path': 'D:/ADLM Data/body_meshes/1107906/body_surface_mesh.pt',
#   'old_id': 1305868,
#   'sex': 'male'},
#  '1108111': {'path': 'D:/ADLM Data/body_meshes/1108111/body_surface_mesh.pt',
#   'old_id': 5060329,
#   'sex': 'male'},
#  '1108189': {'path': 'D:/ADLM Data/body_meshes/1108189/body_surface_mesh.pt',
#   'old_id': 3561951,
#   'sex': 'male'},
#  '1108400': {'path': 'D:/ADLM Data/body_meshes/1108400/body_surface_mesh.pt',
#   'old_id': 2514538,
#   'sex': 'male'},
#  '1108556': {'path': 'D:/ADLM Data/body_meshes/1108556/body_surface_mesh.pt',
#   'old_id': 4194533,
#   'sex': 'female'},
#  '1108616': {'path': 'D:/ADLM Data/body_meshes/1108616/body_surface_mesh.pt',
#   'old_id': 4515945,
#   'sex': 'male'},
#  '1108698': {'path': 'D:/ADLM Data/body_meshes/1108698/body_surface_mesh.pt',
#   'old_id': 4933440,
#   'sex': 'female'},
#  '1108743': {'path': 'D:/ADLM Data/body_meshes/1108743/body_surface_mesh.pt',
#   'old_id': 1595703,
#   'sex': 'female'},
#  '1109081': {'path': 'D:/ADLM Data/body_meshes/1109081/body_surface_mesh.pt',
#   'old_id': 3204322,
#   'sex': 'female'},
#  '1109159': {'path': 'D:/ADLM Data/body_meshes/1109159/body_surface_mesh.pt',
#   'old_id': 4829428,
#   'sex': 'female'},
#  '1109165': {'path': 'D:/ADLM Data/body_meshes/1109165/body_surface_mesh.pt',
#   'old_id': 2103236,
#   'sex': 'female'},
#  '1109486': {'path': 'D:/ADLM Data/body_meshes/1109486/body_surface_mesh.pt',
#   'old_id': 4365005,
#   'sex': 'female'},
#  '1109927': {'path': 'D:/ADLM Data/body_meshes/1109927/body_surface_mesh.pt',
#   'old_id': 2958349,
#   'sex': 'male'},
#  '1110024': {'path': 'D:/ADLM Data/body_meshes/1110024/body_surface_mesh.pt',
#   'old_id': 5023499,
#   'sex': 'female'},
#  '1110075': {'path': 'D:/ADLM Data/body_meshes/1110075/body_surface_mesh.pt',
#   'old_id': 3249359,
#   'sex': 'male'},
#  '1110149': {'path': 'D:/ADLM Data/body_meshes/1110149/body_surface_mesh.pt',
#   'old_id': 5753093,
#   'sex': 'female'},
#  '1110195': {'path': 'D:/ADLM Data/body_meshes/1110195/body_surface_mesh.pt',
#   'old_id': 2174939,
#   'sex': 'female'},
#  '1110210': {'path': 'D:/ADLM Data/body_meshes/1110210/body_surface_mesh.pt',
#   'old_id': 3135745,
#   'sex': 'male'},
#  '1110236': {'path': 'D:/ADLM Data/body_meshes/1110236/body_surface_mesh.pt',
#   'old_id': 1834977,
#   'sex': 'male'},
#  '1110261': {'path': 'D:/ADLM Data/body_meshes/1110261/body_surface_mesh.pt',
#   'old_id': 3441974,
#   'sex': 'female'},
#  '1110299': {'path': 'D:/ADLM Data/body_meshes/1110299/body_surface_mesh.pt',
#   'old_id': 5994658,
#   'sex': 'male'},
#  '1110340': {'path': 'D:/ADLM Data/body_meshes/1110340/body_surface_mesh.pt',
#   'old_id': 5088302,
#   'sex': 'male'},
#  '1110447': {'path': 'D:/ADLM Data/body_meshes/1110447/body_surface_mesh.pt',
#   'old_id': 3267592,
#   'sex': 'male'},
#  '1110709': {'path': 'D:/ADLM Data/body_meshes/1110709/body_surface_mesh.pt',
#   'old_id': 5271315,
#   'sex': 'male'},
#  '1110881': {'path': 'D:/ADLM Data/body_meshes/1110881/body_surface_mesh.pt',
#   'old_id': 3685633,
#   'sex': 'female'},
#  '1110906': {'path': 'D:/ADLM Data/body_meshes/1110906/body_surface_mesh.pt',
#   'old_id': 2387214,
#   'sex': 'female'},
#  '1111009': {'path': 'D:/ADLM Data/body_meshes/1111009/body_surface_mesh.pt',
#   'old_id': 2109658,
#   'sex': 'male'},
#  '1111171': {'path': 'D:/ADLM Data/body_meshes/1111171/body_surface_mesh.pt',
#   'old_id': 4489710,
#   'sex': 'male'},
#  '1111211': {'path': 'D:/ADLM Data/body_meshes/1111211/body_surface_mesh.pt',
#   'old_id': 5626835,
#   'sex': 'female'},
#  '1111382': {'path': 'D:/ADLM Data/body_meshes/1111382/body_surface_mesh.pt',
#   'old_id': 4591456,
#   'sex': 'male'},
#  '1111778': {'path': 'D:/ADLM Data/body_meshes/1111778/body_surface_mesh.pt',
#   'old_id': 2325340,
#   'sex': 'female'},
#  '1111828': {'path': 'D:/ADLM Data/body_meshes/1111828/body_surface_mesh.pt',
#   'old_id': 4856436,
#   'sex': 'male'},
#  '1112088': {'path': 'D:/ADLM Data/body_meshes/1112088/body_surface_mesh.pt',
#   'old_id': 1750142,
#   'sex': 'male'},
#  '1112109': {'path': 'D:/ADLM Data/body_meshes/1112109/body_surface_mesh.pt',
#   'old_id': 5670686,
#   'sex': 'male'},
#  '1112154': {'path': 'D:/ADLM Data/body_meshes/1112154/body_surface_mesh.pt',
#   'old_id': 2855033,
#   'sex': 'male'},
#  '1112223': {'path': 'D:/ADLM Data/body_meshes/1112223/body_surface_mesh.pt',
#   'old_id': 4520119,
#   'sex': 'female'},
#  '1112367': {'path': 'D:/ADLM Data/body_meshes/1112367/body_surface_mesh.pt',
#   'old_id': 2335394,
#   'sex': 'male'},
#  '1112419': {'path': 'D:/ADLM Data/body_meshes/1112419/body_surface_mesh.pt',
#   'old_id': 1725138,
#   'sex': 'female'},
#  '1112460': {'path': 'D:/ADLM Data/body_meshes/1112460/body_surface_mesh.pt',
#   'old_id': 4159106,
#   'sex': 'male'},
#  '1112561': {'path': 'D:/ADLM Data/body_meshes/1112561/body_surface_mesh.pt',
#   'old_id': 5531371,
#   'sex': 'male'},
#  '1112673': {'path': 'D:/ADLM Data/body_meshes/1112673/body_surface_mesh.pt',
#   'old_id': 3239221,
#   'sex': 'male'},
#  '1112757': {'path': 'D:/ADLM Data/body_meshes/1112757/body_surface_mesh.pt',
#   'old_id': 5570184,
#   'sex': 'female'},
#  '1112942': {'path': 'D:/ADLM Data/body_meshes/1112942/body_surface_mesh.pt',
#   'old_id': 2512273,
#   'sex': 'male'},
#  '1113799': {'path': 'D:/ADLM Data/body_meshes/1113799/body_surface_mesh.pt',
#   'old_id': 4254027,
#   'sex': 'female'},
#  '1113852': {'path': 'D:/ADLM Data/body_meshes/1113852/body_surface_mesh.pt',
#   'old_id': 3060599,
#   'sex': 'male'},
#  '1114014': {'path': 'D:/ADLM Data/body_meshes/1114014/body_surface_mesh.pt',
#   'old_id': 2861951,
#   'sex': 'male'},
#  '1114240': {'path': 'D:/ADLM Data/body_meshes/1114240/body_surface_mesh.pt',
#   'old_id': 1761753,
#   'sex': 'female'},
#  '1114413': {'path': 'D:/ADLM Data/body_meshes/1114413/body_surface_mesh.pt',
#   'old_id': 5917179,
#   'sex': 'male'},
#  '1114426': {'path': 'D:/ADLM Data/body_meshes/1114426/body_surface_mesh.pt',
#   'old_id': 2983603,
#   'sex': 'female'},
#  '1114604': {'path': 'D:/ADLM Data/body_meshes/1114604/body_surface_mesh.pt',
#   'old_id': 5753533,
#   'sex': 'female'},
#  '1114677': {'path': 'D:/ADLM Data/body_meshes/1114677/body_surface_mesh.pt',
#   'old_id': 1407753,
#   'sex': 'female'},
#  '1114682': {'path': 'D:/ADLM Data/body_meshes/1114682/body_surface_mesh.pt',
#   'old_id': 4531387,
#   'sex': 'male'},
#  '1114794': {'path': 'D:/ADLM Data/body_meshes/1114794/body_surface_mesh.pt',
#   'old_id': 2767727,
#   'sex': 'female'},
#  '1114818': {'path': 'D:/ADLM Data/body_meshes/1114818/body_surface_mesh.pt',
#   'old_id': 4413169,
#   'sex': 'male'},
#  '1114850': {'path': 'D:/ADLM Data/body_meshes/1114850/body_surface_mesh.pt',
#   'old_id': 2392836,
#   'sex': 'female'},
#  '1114884': {'path': 'D:/ADLM Data/body_meshes/1114884/body_surface_mesh.pt',
#   'old_id': 1363185,
#   'sex': 'male'},
#  '1114909': {'path': 'D:/ADLM Data/body_meshes/1114909/body_surface_mesh.pt',
#   'old_id': 4255829,
#   'sex': 'female'},
#  '1114963': {'path': 'D:/ADLM Data/body_meshes/1114963/body_surface_mesh.pt',
#   'old_id': 3573369,
#   'sex': 'female'},
#  ...}

# %%
len(map_dict)
# Out:
# 9291

# %%
def edge_visualize(_index, _dict):
    
    sample = torch.load(_dict[_index]["path"])
    
    lines = o3d.utility.Vector2iVector(np.asarray(sample.edge_index.T))
    line_set = o3d.geometry.LineSet(
        points=o3d.utility.Vector3dVector(np.asarray(sample.x)),
        lines=lines)

    line_set.colors = o3d.utility.Vector3dVector([[1, 0, 0] for i in range(len(lines))])

    o3d.visualization.draw_geometries([line_set])
    
def point_cloud_visualize(_index, _dict):
    
    sample = torch.load(_dict[_index]["path"])
    
    pcd = o3d.geometry.PointCloud(points = o3d.utility.Vector3dVector(np.asarray(sample.x)))

    o3d.visualization.draw_geometries([pcd])

# %%
edge_visualize("1009499", map_dict)
